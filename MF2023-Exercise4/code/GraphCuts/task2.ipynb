# %% [markdown]
# ## TASK 2

# %% [markdown]
# ### Optimal labeling for task 1:
# We get maxflow = 19 for this given graph. Manual calculation also confirms that.
# A possible min cut is through the terminal edges between the vertices and sink, this is confirmed by the labeling returning [False False False].

# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Quick helper functions to display the images
def show_two_images(img1, img2):
    # plot the images
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))
    ax1.imshow(img1)
    ax2.imshow(img2)
    ax1.axis('off')
    ax2.axis('off')
    plt.show()

def show_image(img1):
    plt.figure(figsize=(5,5))
    plt.imshow(img1)
    plt.axis('off')
    plt.show()

def read_image(path):
    src_img = cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)
    return src_img

# %% [markdown]
# ### Segmentation for given images:
# The segmentation is severely buggy, unfortunately I have not been able to pinpoint the exact reason as to why. I am assuming that it is a arithmetic / index error at most.
# Images are displayed in decreasing lambda values. (ie. left batman lambda = 1, right batman lambda = 0.002 etc.)

# %%
show_two_images(read_image('test_images/Batman_L1.png'), read_image('test_images/Batman_L002.png'))
show_two_images(read_image('test_images/VanDamme_L1.png'), read_image('test_images/VanDamme_L0001.png '))

# %% [markdown]
# ### Van Damme with new background:

# %%
show_image(read_image('test_images/VanDamme_BG.png'))

# %% [markdown]
# ### Segmentation for my image:
# I have skipped this since my implementation is still quite buggy.

# %%
# show_image(read_image('test_images/my_image.jpg'))

# %% [markdown]
# ### Discussion of benefits of graph cut for image segmentation.
# The first benefit is the accuracy of the segmentation. Since graph cut algorithms minimize an energy function that characterizes the partition of an image, we get the best possible answer for a given criterium. Additionally graph cut algorithms are robust to noise and other artifacts that are common in real-world images. The energy function used in graph cut algorithms is designed to account for noise and other irregularities in the image. Finally the graph cut algorithms can be easily modified based on prior knowledge on the image / task ahead.
